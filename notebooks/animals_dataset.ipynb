# %%
# !pip install odfpy
# Out:
# Requirement already satisfied: odfpy in /home/frauke/miniconda3/lib/python3.10/site-packages (1.4.1)
# Requirement already satisfied: defusedxml in /home/frauke/miniconda3/lib/python3.10/site-packages (from odfpy) (0.7.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../../MLZoo/animals_dictionary.ods')

# %%
df.head()
# Out:
#                     name gestation_period _months incubation_period_month  \
# 0               Aardvark                        7          not applicable
# 1  Abyssinian Guinea Pig                        2          not applicable
# 2         Ackie Monitor            not applicable                       6
# 3      Admiral Butterfly           not applicable                       1
# 4          African Civet                      2.5          not applicable
#
#         diet                                   location    group    skin_type  \
# 0   Omnivore                         Sub-Saharan Africa   Mammal         Hair
# 1   Omnivore                              South America   Mammal          Fur
# 2  Carnivore                                  Australia  Reptile       Scales
# 3  Herbivore  North and South America, Europe, and Asia   Insect  Exoskeleton
# 4   Omnivore                  across sub-Saharan Africa   Mammal          Fur
#
#    max_speed_kmh  lifespan_yrs  weight_min_kg  weight_max_kg  \
# 0          40.23          23.0           60.0        80.0000
# 1           6.44           5.5            0.9         1.4000
# 2          18.00          17.5            8.0         8.0000
# 3          15.00           0.9            NaN         0.0003
# 4            NaN          17.5            1.4         4.5000
#
#    length_min_meter  length_max_meter      wingspan_m  \
# 0              1.05              2.20  not applicable
# 1              0.02              0.03  not applicable
# 2              0.60              0.70  not applicable
# 3               NaN               NaN            0.06
# 4              0.67              0.84  not applicable
#
#                                          Unnamed: 14
# 0  https://a-z-animals.com/animals/animals-that-s...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN

# %%
df.describe()
# Out:
#        max_speed_kmh  lifespan_yrs  weight_min_kg  weight_max_kg  \
# count      55.000000    105.000000      79.000000      96.000000
# mean       42.403818     17.144762     119.995654     183.382724
# std        32.310497     22.177328     531.573524     803.715976
# min         0.480000      0.000000       0.000100       0.000300
# 25%        19.480000      5.500000       0.170000       0.437500
# 50%        40.000000     12.500000       1.400000       4.500000
# 75%        57.000000     18.000000      22.705000      40.200000
# max       190.000000    167.500000    3600.000000    5400.000000
#
#        length_min_meter  length_max_meter
# count         80.000000         91.000000
# mean           0.641331          1.273708
# std            2.176594          3.188819
# min            0.002000          0.002500
# 25%            0.034000          0.092000
# 50%            0.250000          0.500000
# 75%            0.702500          1.200000
# max           19.500000         26.300000

# %%
#df=df[df['species_english']!='Mexican free-tailed bat']
#df=df[df['body_mass_mean_kg']<=30]

# %%
plt.scatter(df["max_speed_kmh"],df["weight_min_kg"])
#plt.scatter(np.log10(df[df['type']=='mammal']['body_mass_mean_kg']), df[df['type']=='mammal']['max_speed_min_kmh'], s=5);
#plt.scatter(df[df['type']=='mammal']['max_speed_min_kmh'],np.log10(df[df['type']=='mammal']['body_mass_mean_kg']), s=5);

# %%
df.groupby('group').describe()
# Out:
#            weight_min_kg                                                     \
#                    count        mean         std     min       25%      50%
# group
# Amphibian            5.0    0.261400    0.379137  0.0020  0.025000   0.0600
# Arachnid             0.0         NaN         NaN     NaN       NaN      NaN
# Bird                13.0    0.732269    0.985067  0.0030  0.011000   0.2200
# Fish                10.0   39.749000   70.038864  0.2000  0.750000   4.0500
# Insect               8.0    0.024026    0.029482  0.0001  0.000776   0.0225
# Invertebra           0.0         NaN         NaN     NaN       NaN      NaN
# Mammal              31.0  281.015806  828.942904  0.6800  3.000000  20.4100
# Reptile             12.0   29.971500   63.821717  0.0060  0.273750   0.8150
# Ticks                0.0         NaN         NaN     NaN       NaN      NaN
#
#                             weight_max_kg              ... length_min_meter  \
#                75%      max         count        mean  ...              75%
# group                                                  ...
# Amphibian    0.320     0.90           6.0    0.525833  ...          0.04625
# Arachnid       NaN      NaN           1.0    0.060000  ...          0.05425
# Bird         1.000     3.00          15.0    2.056980  ...          0.41500
# Fish        29.285   200.00          17.0   62.755294  ...          0.71000
# Insect       0.027     0.09          11.0    0.054027  ...          0.01150
# Invertebra     NaN      NaN           0.0         NaN  ...              NaN
# Mammal      60.600  3600.00          32.0  487.454687  ...          0.93750
# Reptile      9.975   181.00          14.0   64.620536  ...          0.90250
# Ticks          NaN      NaN           0.0         NaN  ...          0.00500
#
#                    length_max_meter                                       \
#                max            count      mean       std     min      25%
# group
# Amphibian    0.110              5.0  0.115200  0.082751  0.0450  0.05000
# Arachnid     0.070              2.0  0.006500  0.002121  0.0050  0.00575
# Bird         0.890             12.0  0.490833  0.330852  0.1000  0.26750
# Fish         1.800             17.0  1.722588  3.049542  0.0800  0.30000
# Insect       0.200             14.0  0.062600  0.128407  0.0025  0.00725
# Invertebra     NaN              0.0       NaN       NaN     NaN      NaN
# Mammal      19.500             21.0  2.294333  5.555924  0.0300  0.53000
# Reptile      1.520             19.0  1.633263  2.114894  0.0500  0.24100
# Ticks        0.005              1.0  0.055000       NaN  0.0550  0.05500
#
#
#                50%      75%     max
# group
# Amphibian   0.1110  0.12000   0.250
# Arachnid    0.0065  0.00725   0.008
# Bird        0.3950  0.65750   1.200
# Fish        0.9100  1.55000  13.120
# Insect      0.0125  0.03600   0.460
# Invertebra     NaN      NaN     NaN
# Mammal      1.0400  1.80000  26.300
# Reptile     1.2000  1.95500   9.000
# Ticks       0.0550  0.05500   0.055
#
# [9 rows x 32 columns]

# %%
#plt.scatter(df['max_speed_min_kmh'],np.log10(df['body_mass_mean_kg']), s=5);
plt.scatter(df['weight_min_kg'],df['max_speed_kmh'], s=5);
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[91], line 2
#       1 #plt.scatter(df['max_speed_min_kmh'],np.log10(df['body_mass_mean_kg']), s=5);
# ----> 2 plt.scatter(df['weight_min_kg'],df['max_speed_kmh'], s=5)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/pyplot.py:2862, in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, data, **kwargs)
#    2857 @_copy_docstring_and_deprecators(Axes.scatter)
#    2858 def scatter(
#    2859         x, y, s=None, c=None, marker=None, cmap=None, norm=None,
#    2860         vmin=None, vmax=None, alpha=None, linewidths=None, *,
#    2861         edgecolors=None, plotnonfinite=False, data=None, **kwargs):
# -> 2862     __ret = gca().scatter(
#    2863         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2864         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#    2865         edgecolors=edgecolors, plotnonfinite=plotnonfinite,
#    2866         **({"data": data} if data is not None else {}), **kwargs)
#    2867     sci(__ret)
#    2868     return __ret
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4673, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4667         linewidths = [
#    4668             lw if lw is not None else mpl.rcParams['lines.linewidth']
#    4669             for lw in linewidths]
#    4671 offsets = np.ma.column_stack([x, y])
# -> 4673 collection = mcoll.PathCollection(
#    4674     (path,), scales,
#    4675     facecolors=colors,
#    4676     edgecolors=edgecolors,
#    4677     linewidths=linewidths,
#    4678     offsets=offsets,
#    4679     offset_transform=kwargs.pop('transform', self.transData),
#    4680     alpha=alpha,
#    4681 )
#    4682 collection.set_transform(mtransforms.IdentityTransform())
#    4683 if colors is None:
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/collections.py:994, in PathCollection.__init__(self, paths, sizes, **kwargs)
#     980 def __init__(self, paths, sizes=None, **kwargs):
#     981     """
#     982     Parameters
#     983     ----------
#    (...)
#     991         Forwarded to `.Collection`.
#     992     """
# --> 994     super().__init__(**kwargs)
#     995     self.set_paths(paths)
#     996     self.set_sizes(sizes)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File ~/miniconda3/lib/python3.10/site-packages/matplotlib/collections.py:192, in Collection.__init__(self, edgecolors, facecolors, linewidths, linestyles, capstyle, joinstyle, antialiaseds, offsets, offset_transform, norm, cmap, pickradius, hatch, urls, zorder, **kwargs)
#     189     self._joinstyle = None
#     191 if offsets is not None:
# --> 192     offsets = np.asanyarray(offsets, float)
#     193     # Broadcast (2,) -> (1, 2) but nothing else.
#     194     if offsets.shape == (2,):
#
# ValueError: could not convert string to float: ' '

# %%
df2 = pd.read_excel('../../MLZoo/animals_mass_speed.ods')

# %%
df2.head()
# Out:
#     species_latin species_detail_latin species_detail_english  body_mass_kg  \
# 0     Proboscidae   Loxodonta africana       African elephant        6000.0
# 1     Proboscidae      Elephas maximus         Asian elephant        4000.0
# 2  Perissodactyla  Ceratotherium simum       white rhinoceros        3000.0
# 3  Perissodactyla     Diceros bicornis            black rhino        1400.0
# 4  Perissodactyla       Equus caballus                  horse         400.0
#
#    max_running_speed
# 0               35.0
# 1               26.0
# 2               25.0
# 3               45.0
# 4               70.0

# %%
#plt.scatter(np.log10(df2['body_mass_kg']), df2['max_running_speed'], s=5);
plt.scatter((df2['body_mass_kg']), df2['max_running_speed'], s=5);
