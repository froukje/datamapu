# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../../MLZoo/animals_mass_speed.ods')

# %%
df.head()
# Out:
#     species_latin species_detail_latin species_detail_english  body_mass_kg  \
# 0     Proboscidae   Loxodonta africana       African elephant        6000.0
# 1     Proboscidae      Elephas maximus         Asian elephant        4000.0
# 2  Perissodactyla  Ceratotherium simum       white rhinoceros        3000.0
# 3  Perissodactyla     Diceros bicornis            black rhino        1400.0
# 4  Perissodactyla       Equus caballus                  horse         400.0
#
#    max_running_speed
# 0               35.0
# 1               26.0
# 2               25.0
# 3               45.0
# 4               70.0

# %%
df.describe()
# Out:
#        body_mass_kg  max_running_speed
# count    107.000000         107.000000
# mean     278.682477          46.585981
# std      839.610150          26.835211
# min        0.016000           2.400000
# 25%        1.700000          22.500000
# 50%       34.000000          50.000000
# 75%      142.500000          65.000000
# max     6000.000000         110.000000

# %%
plt.scatter(df['body_mass_kg'], df['max_running_speed'], s=5);

# %%
df.groupby('species_latin').describe()
# Out:
#                body_mass_kg                                                 \
#                       count         mean          std       min        25%
# species_latin
# Artiodactyla           36.0   331.944444   659.460643    20.000    50.0000
# Carnivora              21.0    76.190476   109.083738     3.000    10.0000
# Edentata                1.0     4.000000          NaN     4.000     4.0000
# Insectivora             3.0     0.072000     0.048497     0.016     0.0580
# Lagomorpha              8.0     2.850000     1.238663     1.500     1.8000
# Marsupialia             3.0    18.341333    27.529866     0.024     2.5120
# Perissodactyla          7.0   851.428571  1031.833781   250.000   280.0000
# Primates                3.0    70.000000    57.000000    13.000    41.5000
# Proboscidae             2.0  5000.000000  1414.213562  4000.000  4500.0000
# Rodentia               23.0     0.738478     1.978568     0.016     0.0325
#
# ...
