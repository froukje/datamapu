# %%
# !pip install odfpy
# Out:
# Requirement already satisfied: odfpy in /home/frauke/miniconda3/lib/python3.10/site-packages (1.4.1)
# Requirement already satisfied: defusedxml in /home/frauke/miniconda3/lib/python3.10/site-packages (from odfpy) (0.7.1)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('../../MLZoo/animals.ods')

# %%
df.head()
# Out:
#      type                  species_english  body_mass_mean_kg  \
# 0    bird                 Peregrine falcon             0.8825
# 1    bird                     Golden eagle             4.4750
# 2    bird  White-throated needletail swift             0.1150
# 3    bird                   Eurasian hobby             0.2300
# 4  mammal          Mexican free-tailed bat             0.0380
#
#    body_mass_kg_min_male  body_mass_kg_max_male  body_mass_kg_min_female  \
# 0                  0.330                  1.000                    0.700
# 1                  2.800                  4.600                    3.800
# 2                  0.110                  0.120                    0.110
# 3                  0.175                  0.285                    0.175
# 4                  0.007                  0.012                    0.007
#
#    body_mass_kg_max_female  max_speed_min_kmh  max_speed_max_kmh  \
# 0                    1.500              389.0                NaN
# 1                    6.700              240.0              320.0
# 2                    0.120              169.0                NaN
# 3                    0.285              160.0                NaN
# 4                    0.012              160.0                NaN
#
#            class                                        Unnamed: 10  \
# 0  Flight-diving     https://en.wikipedia.org/wiki/Peregrine_falcon
# 1  Flight-diving         https://en.wikipedia.org/wiki/Golden_eagle
# 2         Flight  https://en.wikipedia.org/wiki/White-throated_n...
# 3         Flight       https://en.wikipedia.org/wiki/Eurasian_hobby
# 4         Flight  https://en.wikipedia.org/wiki/Mexican_free-tai...
#
#                                      Unnamed: 11
# 0  https://en.wikipedia.org/wiki/Fastest_animals
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN

# %%
df.describe()
# Out:
#        body_mass_mean_kg  body_mass_kg_min_male  body_mass_kg_max_male  \
# count          51.000000                34.0000              44.000000
# mean          157.836054                68.7700             202.773682
# std           237.329381               116.9851             299.033778
# min             0.020500                 0.0070               0.012000
# 25%             4.362500                 2.8000               6.525000
# 50%            58.000000                20.0000              71.000000
# 75%           157.500000                75.0000             208.750000
# max          1010.000000               425.0000            1192.000000
#
#        body_mass_kg_min_female  body_mass_kg_max_female  max_speed_min_kmh  \
# count                24.000000                33.000000          53.000000
# mean                 34.879583               137.874697          87.101698
# std                  66.210371               228.471898          61.229955
# min                   0.007000                 0.012000          20.920000
# 25%                   1.160000                 4.400000          50.000000
# 50%                   5.500000                42.000000          70.000000
# 75%                  34.250000               135.000000         109.190000
# max                 300.000000               822.000000         389.000000
#
#        max_speed_max_kmh
# count           25.00000
# mean            78.72800
# std             52.71357
# min             43.00000
# 25%             60.00000
# 50%             70.00000
# 75%             80.00000
# max            320.00000

# %%
df=df[df['species_english']!='Mexican free-tailed bat']
#df=df[df['body_mass_mean_kg']<=30]

# %%
plt.scatter(np.log10(df[df['type']=='mammal']['body_mass_mean_kg']), df[df['type']=='mammal']['max_speed_min_kmh'], s=5);
#plt.scatter(df[df['type']=='mammal']['max_speed_min_kmh'],np.log10(df[df['type']=='mammal']['body_mass_mean_kg']), s=5);

# %%
df.groupby('type').describe()
# Out:
#         body_mass_mean_kg                                                    \
#                     count       mean         std      min        25%    50%
# type
# bird                 15.0   37.36935   86.636426   0.1150    0.97875    3.6
# fish                  5.0  360.40000  327.369516  90.0000  100.00000  180.0
# mammal               25.0  195.70882  244.077612   0.0205   34.50000  128.5
# reptile               5.0  158.86800  303.774119   1.6000    2.74000   20.0
#
#                         body_mass_kg_min_male              ...  \
#             75%     max                 count        mean  ...
# type                                                       ...
# bird      22.20   330.0                  13.0   27.935231  ...
# fish     682.00   750.0                   1.0   60.000000  ...
# mammal   213.75  1010.0                  18.0  106.167500  ...
# reptile   70.00   700.0                   1.0    4.000000  ...
#
#         max_speed_min_kmh         max_speed_max_kmh                         \
#                       75%     max             count       mean         std
# type
# bird               156.50  389.00               4.0  115.75000  136.206644
# fish               109.19  132.00               0.0        NaN         NaN
# mammal              70.38  109.40              21.0   71.67619   15.009560
# reptile             35.41   40.23               0.0        NaN         NaN
#
#
#           min    25%   50%    75%    max
# type
# bird     43.0  48.25  50.0  117.5  320.0
# fish      NaN    NaN   NaN    NaN    NaN
# mammal   55.0  64.00  70.0   80.0  120.7
# reptile   NaN    NaN   NaN    NaN    NaN
#
# [4 rows x 56 columns]

# %%
#plt.scatter(df['max_speed_min_kmh'],np.log10(df['body_mass_mean_kg']), s=5);
plt.scatter(df['body_mass_mean_kg'],df['max_speed_min_kmh'], s=5);

# %%
df2 = pd.read_excel('../../MLZoo/animals_mass_speed.ods')

# %%
df2.head()
# Out:
#     species_latin species_detail_latin species_detail_english  body_mass_kg  \
# 0     Proboscidae   Loxodonta africana       African elephant        6000.0
# 1     Proboscidae      Elephas maximus         Asian elephant        4000.0
# 2  Perissodactyla  Ceratotherium simum       white rhinoceros        3000.0
# 3  Perissodactyla     Diceros bicornis            black rhino        1400.0
# 4  Perissodactyla       Equus caballus                  horse         400.0
#
#    max_running_speed
# 0               35.0
# 1               26.0
# 2               25.0
# 3               45.0
# 4               70.0

# %%
#plt.scatter(np.log10(df2['body_mass_kg']), df2['max_running_speed'], s=5);
plt.scatter((df2['body_mass_kg']), df2['max_running_speed'], s=5);
